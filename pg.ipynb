# %%
import os
from dotenv import load_dotenv
from config.settings import settings

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY","")
print(f"OPENAI_API_KEY: {OPENAI_API_KEY}")
print(f"settings.OPENAI_API_KEY: {settings.openai_api_key}")
# Out:
# OPENAI_API_KEY: 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
# settings.OPENAI_API_KEY: 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
